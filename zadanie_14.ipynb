# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#funkcje wyliczające punkty metodą Eulera
def f1(y):
    return y**2


def f2(y2):
        return 4 + 0.4*y2
    

def euler(a,b,y0):
    y = [y0]
    i = np.arange(9)
    Xi = a+i*h
    for index in range(8):
        y.append(y[index] + h*f1(y[index]))
    return Xi,y


def euler_y2(a,b,y0):
    y = [y0]
    i = np.arange(9)
    Xi = a+i*h
    for index in range(8):
        y.append(y[index] + h*f2(y[index])- 0.5*np.array(y1)[index])
    return Xi,y

# %%
#definiowanie zmiennych
h = 0.1
a = 0
b = 1
y10 = 2
y20 = -3

# %%
x1,y1 = euler(a,h,y10)
plt.plot(x1,y1)
plt.scatter(x1,y1)

# %%
x2,y2 = euler_y2(a,h,y20)
plt.plot(x2,y2)
plt.scatter(x2,y2)
