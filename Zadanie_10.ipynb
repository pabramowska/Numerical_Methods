# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dx=0.5
calka=[]
for x in np.arange(-2,1,0.05):
    calka.append((np.exp(x**2))*dx)
x=[x for x in np.arange(-2,1,0.05)]
plt.plot(x,calka)
plt.bar(x,calka,alpha=0.2,width=0.05,ec='k')
# Out:
# <BarContainer object of 60 artists>
